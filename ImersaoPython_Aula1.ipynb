# %% [markdown]
# <a href="https://colab.research.google.com/github/fcasersilva/ImersaoPython2025/blob/main/ImersaoPython_Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fcasersilva/ImersaoPython2025/refs/heads/main/ImersaoPython_Aula1.ipynb')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-560007016.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('https://raw.githubusercontent.com/fcasersilva/ImersaoPython2025/refs/heads/main/ImersaoPython_Aula1.ipynb')
#
# ...

# %%
df.head()
# Out:
#                        {
# "nbformat": 4        NaN
# "nbformat_minor": 0  NaN
# "metadata": {        NaN
#   "colab": {         NaN
#     "provenance": [] NaN
