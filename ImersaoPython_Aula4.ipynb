# %% [markdown]
# <a href="https://colab.research.google.com/github/fcasersilva/ImersaoPython2025/blob/main/ImersaoPython_Aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AULA 01 - EXPLORE DADOS COM PANDA

# %%
import pandas as pd

# %%
# lendo a bade de dados (link do arquivo raw do github)
# nesse caso foi usado uma tabela do site https://www.kaggle.com/
df = pd.read_csv('https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv')

# %%
df.head() # dentro do parenteses vc pode colocar o numero de linhas a ser mostradada, ou ele mostrara apenas as 5 primeiras linhas
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
#entendendo melhor quais são os dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
# pedindo uma descrição das infos
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape #nao tem o parenteses por ser um atributo. Nesse caso está mostrando (linhas, colunas)
# Out:
# (133349, 11)

# %%
# para melhor visulaisar podemos pedir um print
# nesse caso cria-se 2 variaveis (por ex. linha e coluna) e pede pra mostrar
linhas, colunas = df.shape[0], df.shape[1]
print('numero de linhas:', linhas)
print('numero de colunas:', colunas)
# Out:
# numero de linhas: 133349
# numero de colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Traduzir os nomes das colunas do df (feito com um prompt na IA)
#alterado algumas traduções para melhor entendimento
colunas_traduzidas = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'tipo_contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

df = df.rename(columns=colunas_traduzidas) #pode ser usado df.replace tbm
display(df.head())
#sempre interessante verificar se esta correto antes de rodar
# Out:
#       ano senioridade tipo_contrato               cargo  salario moeda  \
# 0  2025.0          SE            FT  Solutions Engineer   214000   USD
# 1  2025.0          SE            FT  Solutions Engineer   136000   USD
# 2  2025.0          MI            FT       Data Engineer   158800   USD
# 3  2025.0          MI            FT       Data Engineer   139200   USD
# 4  2025.0          EN            FT       Data Engineer    90000   USD
#
#       usd residencia  remoto empresa tamanho_empresa
# 0  214000         US     100      US               M
# 1  136000         US     100      US               M
# 2  158800         AU       0      AU               M
# 3  139200         AU       0      AU               M
# 4   90000         US       0      US               M

# %%
#analiazando a frequencia de um cargpo
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['tipo_contrato'].value_counts()
# Out:
# tipo_contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
'''
0 - presencial
100 - remoto
50 - hibrido
fonte - https://www.kaggle.com/
'''
# Out:
# '\n0 - presencial\n100 - remoto\n50 - hibrido\nfonte - https://www.kaggle.com/\n'

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
# Large / Medium / Small

# %%
# Traduzir as categorias da coluna 'senioridade'
traducoes_senioridade = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}

df['senioridade'] = df['senioridade'].replace(traducoes_senioridade)
display(df['senioridade'].value_counts())
# Out:
# senioridade
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
# Traduzir as categorias da coluna 'tipo_contrato'
traducoes_tipo_contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

df['tipo_contrato'] = df['tipo_contrato'].replace(traducoes_tipo_contrato)
display(df['tipo_contrato'].value_counts())
# Out:
# tipo_contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
# Traduzir as categorias da coluna 'tamanho_empresa'
traducoes_tamanho_empresa = {
    'M': 'Media',
    'L': 'Grande',
    'S': 'Pequena'
}

df['tamanho_empresa'] = df['tamanho_empresa'].replace(traducoes_tamanho_empresa)
display(df['tamanho_empresa'].value_counts())
# Out:
# tamanho_empresa
# Media      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
# Traduzir as categorias da coluna 'remoto'
traducoes_remoto = {
    0: 'Presencial',
    100: 'Remoto',
    50: 'Hibrido'
}

df['remoto'] = df['remoto'].replace(traducoes_remoto)
display(df['remoto'].value_counts())
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Hibrido          319
# Name: count, dtype: int64

# %%
# verificando como ficou a tabela depois das alterações
df.head()
# Out:
#       ano senioridade   tipo_contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %%
# analizando alguns parametros
df.describe(include='object')
# Out:
#        senioridade   tipo_contrato           cargo   moeda residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Senior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Media
# freq        105312  119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            usd
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %% [markdown]
# # AULA 02 - APRENDA A LIMPAR E PREPARAR DADOS

# %%
df.isnull() #celuas vazias = true com conteudo = false
# Out:
#           ano  senioridade  tipo_contrato  cargo  salario  moeda    usd  \
# 0       False        False          False  False    False  False  False
# 1       False        False          False  False    False  False  False
# 2       False        False          False  False    False  False  False
# 3       False        False          False  False    False  False  False
# 4       False        False          False  False    False  False  False
# ...       ...          ...            ...    ...      ...    ...    ...
# 133344  False        False          False  False    False  False  False
# 133345  False        False          False  False    False  False  False
# 133346  False        False          False  False    False  False  False
# 133347  False        False          False  False    False  False  False
# 133348  False        False          False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# ...

# %%
df.isnull().sum() #mostra a qnt de campos vazios em cada linha
# Out:
# ano                10
# senioridade         0
# tipo_contrato       0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique() #quais os valores do campo
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
#nan = nulo (not a number)

# %%
df[df.isnull().any(axis=1)] # mostrando quais os campos em branco/com erro
# Out:
#         ano senioridade   tipo_contrato                      cargo  salario  \
# 5588    NaN      Senior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Junior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Senior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Senior  Tempo Integral                   Engineer   112000
# 131000  NaN      Senior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Senior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Junior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %%
#colocando novas infos/ excluindo de acordo com alguma regra
#criando um novo df para exemplo
#importando uma bliblioteca ´para manipulação numérica
import numpy as np

df_salarios = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", 'Val'],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
})
#atentar para o camel case em DataFrame

#preencher valores nulos com a media dos outros
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
#round2 = arredondar 2 casas

df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())
#usando a mediana ao inves de media

df_salarios #mostrar novamente a tabela
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
# Outro exemplo - monitorando temperaturas
df_temperatura = pd.DataFrame({
    'dia': ['SEG', 'TER', 'QUA', 'QUI', 'SEX'],
    'temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperatura['preenchido_ffill'] = df_temperatura['temperatura'].ffill()
#ffill (foward fill) preenche com o valor anterior

df_temperatura
# Out:
#    dia  temperatura  preenchido_ffill
# 0  SEG         30.0              30.0
# 1  TER          NaN              30.0
# 2  QUA          NaN              30.0
# 3  QUI         28.0              28.0
# 4  SEX         27.0              27.0

# %%
df_temperatura = pd.DataFrame({
    'dia': ['SEG', 'TER', 'QUA', 'QUI', 'SEX'],
    'temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperatura['preenchido_bfill'] = df_temperatura['temperatura'].bfill()
#bfill (back fill) preenche com o valor posterior

df_temperatura
# Out:
#    dia  temperatura  preenchido_bfill
# 0  SEG         30.0              30.0
# 1  TER          NaN              28.0
# 2  QUA          NaN              28.0
# 3  QUI         28.0              28.0
# 4  SEX         27.0              27.0

# %%
# preenchendo com condição
df_cidades = pd.DataFrame({
  'nome': ["Ana", "Bruno", "Carlos", "Daniele", 'Val'],
  'cidade': ['São Paulo', np.nan, 'Curitiba', np.nan, "Belém", ]
})

df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna("Não informada")
df_cidades

#muitas vezes a IA consgue ajudar com algum erro e até corrigir
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informada
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informada
# 4      Val      Belém             Belém

# %%
'''
retomando a tabela com os anos
como são poucas pessoas (10) numa tabela muito grande optamos por excluir
e para nao sobreescrever a tabela original vamos criar uma nova
'''
df_limpa = df.dropna()

# %%
#verif se deletou os "erros"
df_limpa.isnull().sum()
# Out:
# ano                0
# senioridade        0
# tipo_contrato      0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpa.head()
# Out:
#       ano senioridade   tipo_contrato               cargo  salario moeda  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %%
#corrigindo a questão do decimal no ano
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133349 non-null  object
#  2   tipo_contrato    133349 non-null  object
#  3   cargo            133349 non-null  object
#  4   salario          133349 non-null  int64
#  5   moeda            133349 non-null  object
#  6   usd              133349 non-null  int64
#  7   residencia       133349 non-null  object
#  8   remoto           133349 non-null  object
#  9   empresa          133349 non-null  object
#  10  tamanho_empresa  133349 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 11.2+ MB

# %%
df_limpa = df_limpa.assign(ano = df_limpa['ano'].astype('int64'))
df_limpa.head()
# Out:
#     ano senioridade   tipo_contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %% [markdown]
# # AULA 03 - CRIE GRÁFICOS E CONTE HISTÓRIAS COM DADOS

# %%
df_limpa.head()
# Out:
#     ano senioridade   tipo_contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Media
# 1  136000         US      Remoto      US           Media
# 2  158800         AU  Presencial      AU           Media
# 3  139200         AU  Presencial      AU           Media
# 4   90000         US  Presencial      US           Media

# %%
# plotando um grafico com a biblioteca Panda
# outras bibliotecas para trabalhatr com Puthon são a Matplotlin e Seaborn
df_limpa['senioridade'].value_counts().plot(kind='bar', title='Distribuição senioridade')
# Out:
# <Axes: title={'center': 'Distribuição senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpa, x='senioridade', y='usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
# melhorando a tabela
import matplotlib.pyplot as plt

# %%
# definindo o tamanho dos graficos
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpa, x='senioridade', y='usd')
plt.title('Distribuição senioridade')
plt.xlabel('senioridade')
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
# sem o comando plt.show o grafico acaba vindo algumas infos da figura/codigo
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpa, x='senioridade', y='usd')
plt.title('Distribuição senioridade')
plt.xlabel('senioridade')
plt.ylabel('Salário Médio Anual (USD)')
# Out:
# Text(0, 0.5, 'Salário Médio Anual (USD)')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpa, x='senioridade', y='usd')
plt.title('Distribuição senioridade')
plt.xlabel('senioridade')
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
# organizando por ordem de tamanho
df_limpa.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Junior        99034.963267
# Name: usd, dtype: float64

# %%
# colocando esse valores numa variavel para fazer a ordenação no grafico
ordem = df_limpa.groupby('senioridade')['usd'].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['Executivo', 'Senior', 'Pleno', 'Junior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8,5)) # (largura, altura)
sns.barplot(data=df_limpa, x='senioridade', y='usd', order=ordem)
plt.title('Distribuição senioridade')
plt.xlabel('senioridade')
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
# caso queira ver de maneira crescente
ordem = df_limpa.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpa, x='senioridade', y='usd', order=ordem)
plt.title('Distribuição senioridade')
plt.xlabel('senioridade')
plt.ylabel('Salário Médio Anual (USD)')
plt.show()

# %%
# distribuição salarial
plt.figure(figsize=(8,4))
sns.histplot(df_limpa['usd'], bins=50, kde=True) # kde é a linha de distribuição
# histograma onde bins é o o intervalo
plt.title('Distribuição Anual de Salários')
plt.xlabel('Salãrio Anual (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
# diminiundo o intervalo
plt.figure(figsize=(10,5))
sns.histplot(df_limpa['usd'], bins=500, kde=True)
plt.title('Distribuição Anual de Salários')
plt.xlabel('Salãrio Anual (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
# diminiundo o intervalo
plt.figure(figsize=(10,5))
sns.histplot(df_limpa['usd'], bins=5, kde=True)
plt.title('Distribuição Anual de Salários')
plt.xlabel('Salãrio Anual (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
# diminiundo o intervalo
plt.figure(figsize=(10,5))
sns.histplot(df_limpa['usd'], bins=50, kde=True)
plt.title('Distribuição Anual de Salários')
plt.xlabel('Salãrio Anual (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
# outro tipo de grafico
plt.figure(figsize=(8,5))
sns.boxplot(data=df_limpa, x='usd')
plt.title('BoxPlot de Salários')
plt.xlabel('Salário (USD)')
plt.show()

# %%
# fazendo um boxplot por cargo
ordem_senioridade = ['Junior', 'Pleno', 'Senior', 'Executivo']
plt.figure(figsize=(10,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpa, order=ordem_senioridade)
plt.title('BoxPlot da Distribuição de Senioriodades')
plt.xlabel('senioridade')
plt.ylabel('Salario em USD')
plt.show()

# %%
# mexendo nas cores
ordem_senioridade = ['Junior', 'Pleno', 'Senior', 'Executivo']
plt.figure(figsize=(10,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpa, order=ordem_senioridade, palette='Set2', hue='senioridade')
# Set2 é uma plaeta de cores p´re definida na biblioteca e Hue o parametro que quero destacar
plt.title('BoxPlot da Distribuição de Senioriodades')
plt.xlabel('senioridade')
plt.ylabel('Salario em USD')
plt.show()

# %%
# importanto uma biclioteca para usar dashboards interativos
import plotly.express as px

# %%
#Feito com IA

# Calcular a média salarial por senioridade
media_salario_por_senioridade = df_limpa.groupby('senioridade')['usd'].mean().reset_index()
# reset index pega somente os nokes da coluna

# Ordenar os dados pela média salarial
ordem_senioridade = ['Junior', 'Pleno', 'Senior', 'Executivo']
media_salario_por_senioridade['senioridade'] = pd.Categorical(media_salario_por_senioridade['senioridade'], categories=ordem_senioridade, ordered=True)
media_salario_por_senioridade = media_salario_por_senioridade.sort_values('senioridade')


# Criar o gráfico de barras interativo com Plotly
fig = px.bar(media_salario_por_senioridade,
             x='senioridade',
             y='usd',
             title='Média Salarial por Senioridade',
             labels={'senioridade': 'Senioridade', 'usd': 'Média Salarial Anual (USD)'},
             color='senioridade', # Color bars by seniority level
             category_orders={'senioridade': ordem_senioridade}) # Ensure the correct order

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# mesmo grafico anterior porem com uma codigo mais simples:

senioridade_media_salario = df_limpa.groupby('senioridade')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(senioridade_media_salario,
             x='senioridade',
             y='usd',
             title='Média Salarial por Senioridade',
             labels={'senioridade': 'Nível de Senioridade', 'usd': 'Média Salarial (USD)'}
             )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# criando graficos de pizza /torta (geralmente usando com ate 3 categorias)

remoto_contagem = df_limpa['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# convertendo em grafico de rosca e colocanco os rotulos
remoto_contagem = df_limpa['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             hole=0.5
            )
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # EXERCÍCIO 01 - CRIAR UM GRÁFICO DE MEDIA SALARIAL DOS CIENTISTA DE DADOS POR PAÍS

# %%
df_ds = df_limpa[df_limpa['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia')['usd'].mean().reset_index()

fig = px.bar(media_ds_pais,
             x='residencia',
             y='usd',
             title='Salário Médio de Cientista de Dados por País',
             labels={'residencia': 'País', 'usd': 'Salário Médio (USD)'}
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # AULA 04 - CONTRUA UM DASHBOARD INTERATIVO

# %%
'''
apara essa aula será necessário algumas outras rerramentas
1- instalar Python e o VS Code
2- Criar uma pasta para os arquivos
3- Preparar os ambiente de programação usando o seguintes copdigos:

Criando o ambiente Virtual:
python -m venv .venv

Ativar o ambiente virtual em Windows:
.venv\Scripts\Activate

4- Criar um arquivo chamado requirements.txt e adicionar os pacotes necessários

pandas==2.2.3
streamlit==1.44.1
plotly==5.24.1

5- instalando todas as bliblitecas de uma vez só:
pip install -r REQUIREMENTS.txt

'''
# Out:
# '\napara essa aula será necessário algumas outras rerramentas\n1- instalar Python e o VS Code\n2- Criar uma pasta para os arquivos\n3- Preparar os ambiente de programação usando o seguintes copdigos:\n\nCriando o ambiente Virtual:\npython -m venv .venv\n\nAtivar o ambiente virtual em Windows:\n.venv\\Scripts\\Activate\n\n4- Criar um arquivo chamado requirements.txt e adicionar os pacotes necessários\n\npandas==2.2.3\nstreamlit==1.44.1\nplotly==5.24.1\n\n5- instalando todas as bliblitecas de uma vez só:\npip install -r REQUIREMENTS.txt\n\n'

# %% [markdown]
# # EXERCÍCIO 02 - FAZER O MESMO EXERCÍCIO ANTERIOR MOSTRADO NUM MAPA

# %%
# para isso precisamos instalar uma nova biblioteca
# !pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 84.2 MB/s eta 0:00:00
# ...

# %%
import pycountry
# Função para converter ISO-2 para ISO-3 (nome de 2 para 3 letras)
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpa['residencia_iso3'] = df_limpa['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpa[df_limpa['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(
    media_ds_pais,
    locations='residencia_iso3',
    color='usd',
    color_continuous_scale='rdylgn',
    title='Salário médio de Cientista de Dados por país',
    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpa.head() # mostrando que foi criado uma nova cluna com 3 letras para cada pais
# Out:
#     ano senioridade   tipo_contrato               cargo  salario moeda  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Junior  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa residencia_iso3
# 0  214000         US      Remoto      US           Media             USA
# 1  136000         US      Remoto      US           Media             USA
# 2  158800         AU  Presencial      AU           Media             AUS
# 3  139200         AU  Presencial      AU           Media             AUS
# 4   90000         US  Presencial      US           Media             USA

# %%
# salvando esse df para usar como base de dados para o VS Code
df_limpa.to_csv('DF_Final', index=False)
